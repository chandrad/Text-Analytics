# %%
import json
import os

from google.colab import files

license_keys = files.upload()

with open(list(license_keys.keys())[0]) as f:
    license_keys = json.load(f)

# Defining license key-value pairs as local variables
locals().update(license_keys)

# Adding license key-value pairs to environment variables
os.environ.update(license_keys)
# Out:
#      <input type="file" id="files-0361be6b-626f-4bff-aac5-dc655aa236cd" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-0361be6b-626f-4bff-aac5-dc655aa236cd">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving spark_nlp_for_healthcare_spark_ocr_4919.json to spark_nlp_for_healthcare_spark_ocr_4919.json

# %%
license_keys.keys()
# Out:
# dict_keys(['SPARK_NLP_LICENSE', 'SECRET', 'JSL_VERSION', 'PUBLIC_VERSION', 'AWS_ACCESS_KEY_ID', 'AWS_SECRET_ACCESS_KEY', 'AWS_SESSION_TOKEN', 'SPARK_OCR_LICENSE', 'SPARK_OCR_SECRET', 'OCR_VERSION'])

# %%
license_keys['JSL_VERSION']
# Out:
# '3.5.0'

# %%
license_keys['PUBLIC_VERSION']
# Out:
# '3.4.2'

# %%
# Installing pyspark and spark-nlp
! pip install --upgrade -q pyspark==3.1.2 spark-nlp==$PUBLIC_VERSION

# Installing Spark NLP Healthcare
! pip install --upgrade -q spark-nlp-jsl==$JSL_VERSION  --extra-index-url https://pypi.johnsnowlabs.com/$SECRET

# Installing Spark NLP Display Library for visualization
! pip install -q spark-nlp-display
# Out:
#      |████████████████████████████████| 212.4 MB 63 kB/s
#      |████████████████████████████████| 142 kB 21.0 MB/s
#      |████████████████████████████████| 198 kB 57.9 MB/s
#   Building wheel for pyspark (setup.py) ... done
#      |████████████████████████████████| 188 kB 11.3 MB/s
#      |████████████████████████████████| 95 kB 3.4 MB/s
#      |████████████████████████████████| 66 kB 5.1 MB/s

# %%
import json
import os

import sparknlp
import sparknlp_jsl

from sparknlp.base import *
from sparknlp.annotator import *
from sparknlp_jsl.annotator import *

from pyspark.sql import SparkSession
from pyspark.sql import functions as F
from pyspark.ml import Pipeline,PipelineModel

import warnings
warnings.filterwarnings('ignore')

params = {"spark.driver.memory":"16G", 
          "spark.kryoserializer.buffer.max":"2000M", 
          "spark.driver.maxResultSize":"2000M"} 

print("Spark NLP Version :", sparknlp.version())
print("Spark NLP_JSL Version :", sparknlp_jsl.version())

spark = sparknlp_jsl.start(license_keys['SECRET'],params=params)

spark
# Out:
# Spark NLP Version : 3.4.2
# Spark NLP_JSL Version : 3.5.0
#             <div>
#                 <p><b>SparkSession - in-memory</b></p>
#
#         <div>
#             <p><b>SparkContext</b></p>
#
#             <p><a href="http://58bec3e23ca8:4040">Spark UI</a></p>
#
#             <dl>
#               <dt>Version</dt>
#                 <dd><code>v3.1.2</code></dd>
#               <dt>Master</dt>
#                 <dd><code>local[*]</code></dd>
#               <dt>AppName</dt>
#                 <dd><code>Spark NLP Licensed</code></dd>
#             </dl>
#         </div>
#
#             </div>

# %%
# if you want to start the session with custom params as in start function above
from pyspark.sql import SparkSession

def start(SECRET):
    builder = SparkSession.builder \
        .appName("Spark NLP Licensed") \
        .master("local[*]") \
        .config("spark.driver.memory", "16G") \
        .config("spark.serializer", "org.apache.spark.serializer.KryoSerializer") \
        .config("spark.kryoserializer.buffer.max", "2000M") \
        .config("spark.jars.packages", "com.johnsnowlabs.nlp:spark-nlp_2.12:"+PUBLIC_VERSION) \
        .config("spark.jars", "https://pypi.johnsnowlabs.com/"+SECRET+"/spark-nlp-jsl-"+JSL_VERSION+".jar")
      
    return builder.getOrCreate()

#spark = start(SECRET)

# %%
# Annotator that transforms a text column from dataframe into an Annotation ready for NLP
documentAssembler = DocumentAssembler()\
    .setInputCol("text")\
    .setOutputCol("document")
        
sentenceDetector = SentenceDetectorDLModel.pretrained("sentence_detector_dl_healthcare","en","clinical/models")\
    .setInputCols(["document"])\
    .setOutputCol("sentence")
 
# Tokenizer splits words in a relevant format for NLP
tokenizer = Tokenizer()\
    .setInputCols(["sentence"])\
    .setOutputCol("token")

# Clinical word embeddings trained on PubMED dataset
word_embeddings = WordEmbeddingsModel.pretrained("embeddings_clinical","en","clinical/models")\
    .setInputCols(["sentence","token"])\
    .setOutputCol("embeddings")

# NER model trained on i2b2 (sampled from MIMIC) dataset
clinical_ner = MedicalNerModel.pretrained("ner_clinical_large","en","clinical/models")\
    .setInputCols(["sentence","token","embeddings"])\
    .setOutputCol("ner")\
    .setLabelCasing("upper") #decide if we want to return the tags in upper or lower case 

ner_converter = NerConverter()\
    .setInputCols(["sentence","token","ner"])\
    .setOutputCol("ner_chunk")

nlpPipeline = Pipeline(stages=[
        documentAssembler,
        sentenceDetector,
        tokenizer,
        word_embeddings,
        clinical_ner,
        ner_converter])


empty_data = spark.createDataFrame([[""]]).toDF("text")

model = nlpPipeline.fit(empty_data)
# Out:
# sentence_detector_dl_healthcare download started this may take some time.
# Approximate size to download 367.3 KB
# [OK!]
# embeddings_clinical download started this may take some time.
# Approximate size to download 1.6 GB
# [OK!]
# ner_clinical_large download started this may take some time.
# Approximate size to download 13.9 MB
# [OK!]

# %%
clinical_ner.extractParamMap()
# Out:
# {Param(parent='MedicalNerModel_1a8637089929', name='batchSize', doc='Size of every batch'): 64,
#  Param(parent='MedicalNerModel_1a8637089929', name='classes', doc='get the tags used to trained this MedicalNerModel'): ['O',
#   'B-TREATMENT',
#   'I-TREATMENT',
#   'B-PROBLEM',
#   'I-PROBLEM',
#   'B-TEST',
#   'I-TEST'],
#  Param(parent='MedicalNerModel_1a8637089929', name='includeAllConfidenceScores', doc='whether to include all confidence scores in annotation metadata or just the score of the predicted tag'): False,
#  Param(parent='MedicalNerModel_1a8637089929', name='includeConfidence', doc='whether to include confidence scores in annotation metadata'): True,
#  Param(parent='MedicalNerModel_1a8637089929', name='inferenceBatchSize', doc='number of sentences to process in a single batch during inference'): 1,
#  Param(parent='MedicalNerModel_1a8637089929', name='inputCols', doc='previous annotations columns, if renamed'): ['sentence',
#   'token',
#   'embeddings'],
#  Param(parent='MedicalNerModel_1a8637089929', name='labelCasing', doc='Setting all labels of the NER models upper/lower case. values upper|lower'): 'upper',
#  Param(parent='MedicalNerModel_1a8637089929', name='lazyAnnotator', doc='Whether this AnnotatorModel acts as lazy in RecursivePipelines'): False,
#  Param(parent='MedicalNerModel_1a8637089929', name='outputCol', doc='output annotation column. can be left default.'): 'ner',
#  Param(parent='MedicalNerModel_1a8637089929', name='storageRef', doc='unique reference name for identification'): 'clinical'}

# %%
clinical_ner.getClasses()
# Out:
# ['O',
#  'B-TREATMENT',
#  'I-TREATMENT',
#  'B-PROBLEM',
#  'I-PROBLEM',
#  'B-TEST',
#  'I-TEST']

# %%
clinical_ner.getStorageRef()
# Out:
# 'clinical'

# %%
from sparknlp_jsl.compatibility import Compatibility 
import pandas as pd

compatibility = Compatibility(spark)

models = compatibility.findVersion('ner') 

models_df = pd.DataFrame([dict(x) for x in list(models)])
models_df
# Out:
#                              name sparkVersion version language  \
# 0               nerdl_tumour_demo            2   1.7.3       en
# 1              nercrf_tumour_demo            2   1.7.3       en
# 2               nerdl_tumour_demo          2.4   1.8.0       en
# 3              nercrf_tumour_demo          2.4   1.8.0       en
# 4                     nercrf_deid          2.4   1.8.0       en
# ..                            ...          ...     ...      ...
# 453  ner_anatomy_biobert_pipeline          3.0   3.4.1       en
# 454   ner_ade_healthcare_pipeline          3.0   3.4.1       en
# 455     ner_ade_clinical_pipeline          3.0   3.4.1       en
# 456            ner_deid_subentity          3.0   3.4.2       pt
# 457              ner_deid_generic          3.0   3.4.2       pt
#
#                         date readyToUse
# 0    2018-12-19T16:52:37.735       true
# 1    2018-12-19T17:23:53.776       true
# 2    2018-12-22T04:21:25.574       true
# 3    2018-12-22T04:46:26.992       true
# 4    2018-12-23T00:44:17.698       true
# ..                       ...        ...
# 453  2022-03-21T14:43:26.641       true
# 454  2022-03-22T10:16:20.015       true
# 455  2022-03-21T14:55:30.624       true
# 456  2022-04-13T09:04:03.338       true
# 457  2022-04-13T10:49:17.944       true
#
# [458 rows x 6 columns]

# %%
from google.colab import drive
drive.mount("/content/gdrive")
# Out:
# Mounted at /content/gdrive

# %%
import os
import pandas as pd
from ast import literal_eval

mt_samples = pd.read_csv(os.path.join('gdrive/MyDrive/data/negative_articles.csv'), converters={'MeSHDescriptorName': literal_eval,'MeSHQualifierName': literal_eval}, error_bad_lines=False)
mt_samples.head(10)
# Out:
#        PMID                                              Title      Journal  \
# 0  10021330  The surface ectoderm is essential for nephric ...  Development
# 1  10021331  Separation of shoot and floral identity in Ara...  Development
# 2  10021332  Novel regulation of the homeotic gene Scr asso...  Development
# 3  10021333  Apontic binds the translational repressor Brun...  Development
# 4  10021334  Stromal cells mediate retinoid-dependent funct...  Development
# 5  10021336  Inhibition of in vitro enteric neuronal develo...  Development
# 6  10021337  The Drosophila kismet gene is related to chrom...  Development
# 7  10021338  FGF8 induces formation of an ectopic isthmic o...  Development
# 8  10021339  Transcriptional repression by the Drosophila g...  Development
# 9  10021341  The homeobox gene Pitx2: mediator of asymmetri...  Development
#
#                                             Abstract  PublicationYear  \
# 0  The nephric duct is the first epithelial tubul...             1999
# 1  The overall morphology of an Arabidopsis plant...             1999
# 2  Homeotic genes are known to be involved in pat...             1999
# 3  The product of the oskar gene directs posterio...             1999
# 4  The essential role of vitamin A and its metabo...             1999
# 5  The terminal colon is aganglionic in mice lack...             1999
# 6  The Drosophila kismet gene was identified in a...             1999
# 7  Beads containing recombinant FGF8 (FGF8-beads)...             1999
# 8  Early developmental patterning of the Drosophi...             1999
# 9  Left-right asymmetry in vertebrates is control...             1999
#
#                                   MeSHDescriptorName  \
# 0  [Animals, Bone Morphogenetic Protein 4, Bone M...
# 1  [Arabidopsis, Arabidopsis Proteins, Cell Diffe...
# 2  [Amino Acid Sequence, Animals, Antigens, Diffe...
# 3  [3' Untranslated Regions, Animals, Cell Compar...
# 4  [Animals, Cell Differentiation, Down-Regulatio...
# 5  [Animals, Cell Adhesion, Cell Differentiation,...
# 6  [Amino Acid Sequence, Animals, Bacterial Prote...
# 7  [Animals, Body Patterning, Brain Stem, Cerebel...
# 8  [Animals, Animals, Genetically Modified, Bindi...
# 9  [Abnormalities, Multiple, Activins, Amino Acid...
#
#                                    MeSHQualifierName
# 0  [None, None, metabolism, None, None, biosynthe...
# 1  [cytology, None, None, biosynthesis, None, Non...
# 2  [None, None, None, None, None, None, embryolog...
# 3  [metabolism, None, None, None, genetics, None,...
# 4  [None, None, None, None, None, None, abnormali...
# 5  [None, None, None, None, embryology, pharmacol...
# 6  [None, None, None, genetics, None, physiology,...
# 7  [None, drug effects, drug effects, drug effect...
# 8  [None, None, None, genetics, genetics, None, e...
# 9  [embryology, None, None, None, None, None, emb...

# %%
mt_samples_df = spark.createDataFrame(mt_samples)

# %%
samples_df = mt_samples_df.withColumnRenamed("Abstract", "text")

# %%
samples_df.show()
# Out:
# +--------+--------------------+----------------+--------------------+---------------+--------------------+--------------------+
# |    PMID|               Title|         Journal|                text|PublicationYear|  MeSHDescriptorName|   MeSHQualifierName|
# +--------+--------------------+----------------+--------------------+---------------+--------------------+--------------------+
# |10021330|The surface ectod...|     Development|The nephric duct ...|           1999|[Animals, Bone Mo...|[null, null, meta...|
# |10021331|Separation of sho...|     Development|The overall morph...|           1999|[Arabidopsis, Ara...|[cytology, null, ...|
# |10021332|Novel regulation ...|     Development|Homeotic genes ar...|           1999|[Amino Acid Seque...|[null, null, null...|
# |10021333|Apontic binds the...|     Development|The product of th...|           1999|[3' Untranslated ...|[metabolism, null...|
# |10021334|Stromal cells med...|     Development|The essential rol...|           1999|[Animals, Cell Di...|[null, null, null...|
# |10021336|Inhibition of in ...|     Development|The terminal colo...|           1999|[Animals, Cell Ad...|[null, null, null...|
# |10021337|The Drosophila ki...|     Development|The Drosophila ki...|           1999|[Amino Acid Seque...|[null, null, null...|
# |10021338|FGF8 induces form...|     Development|Beads containing ...|           1999|[Animals, Body Pa...|[null, drug effec...|
# |10021339|Transcriptional r...|     Development|Early development...|           1999|[Animals, Animals...|[null, null, null...|
# |10021341|The homeobox gene...|     Development|Left-right asymme...|           1999|[Abnormalities, M...|[embryology, null...|
# |10021343|Mrj encodes a Dna...|     Development|We have identifie...|           1999|[Allantois, Amino...|[abnormalities, n...|
# |10021344|A Drosophila doub...|     Development|The Drosophila do...|           1999|[Amino Acid Seque...|[null, null, null...|
# |10021345|The cardiac homeo...|     Development|Csx/Nkx2.5 is a v...|           1999|[Animals, Cardiov...|[null, embryology...|
# |10021346|Requirement of a ...|     Development|A novel gene, Xin...|           1999|[Amino Acid Seque...|[null, null, null...|
# |10021347|Characterization ...|     Development|On the basis of d...|           1999|[Alternative Spli...|[null, null, null...|
# |10021350|Membrane-tethered...|     Development|Drosophila Armadi...|           1999|[Animals, Armadil...|[null, null, null...|
# |10021463|Bcl-2 and Bcl-XL ...|J. Clin. Invest.|To maintain the i...|           1999|[Animals, Apoptos...|[null, null, null...|
# |10021466|Chlamydial and hu...|J. Clin. Invest.|Both chlamydial a...|           1999|[Cells, Cultured,...|[null, immunology...|
# |10022123|C-myc overexpress...|        Oncogene|p53 monitors geno...|           1999|[Animals, CDC2 Pr...|[null, metabolism...|
# |10022127|TIF1gamma, a nove...|        Oncogene|We report the clo...|           1999|[Amino Acid Seque...|[null, null, null...|
# +--------+--------------------+----------------+--------------------+---------------+--------------------+--------------------+
# only showing top 20 rows

# %%
print(samples_df.limit(1).collect()[0]['text'])
# Out:
# The nephric duct is the first epithelial tubule to differentiate from intermediate mesoderm that is essential for all further urogenital development. In this study we identify the domain of intermediate mesoderm that gives rise to the nephric duct and demonstrate that the surface ectoderm is required for its differentiation. Removal of the surface ectoderm resulted in decreased levels of Sim-1 and Pax-2 mRNA expression in mesenchymal nephric duct progenitors, and caused inhibition of nephric duct formation and subsequent kidney development. The surface ectoderm expresses BMP-4 and we show that it is required for the maintenance of high-level BMP-4 expression in lateral plate mesoderm. Addition of a BMP-4-coated bead to embryos lacking the surface ectoderm restored normal levels of Sim-1 and Pax-2 mRNA expression in nephric duct progenitors, nephric duct formation and the initiation of nephrogenesis. Thus, BMP-4 signaling can substitute for the surface ectoderm in supporting nephric duct morphogenesis. Collectively, these data suggest that inductive interactions between the surface ectoderm, lateral mesoderm and intermediate mesoderm are essential for nephric duct formation and the initiation of urogenital development.

# %%
result = model.transform(samples_df.limit(100)).cache()

# %%
result.show()
# Out:
# +--------+--------------------+----------------+--------------------+---------------+--------------------+--------------------+--------------------+--------------------+--------------------+--------------------+--------------------+--------------------+
# |    PMID|               Title|         Journal|                text|PublicationYear|  MeSHDescriptorName|   MeSHQualifierName|            document|            sentence|               token|          embeddings|                 ner|           ner_chunk|
# +--------+--------------------+----------------+--------------------+---------------+--------------------+--------------------+--------------------+--------------------+--------------------+--------------------+--------------------+--------------------+
# |10021330|The surface ectod...|     Development|The nephric duct ...|           1999|[Animals, Bone Mo...|[null, null, meta...|[{document, 0, 12...|[{document, 0, 14...|[{token, 0, 2, Th...|[{word_embeddings...|[{named_entity, 0...|[{chunk, 70, 90, ...|
# |10021331|Separation of sho...|     Development|The overall morph...|           1999|[Arabidopsis, Ara...|[cytology, null, ...|[{document, 0, 10...|[{document, 0, 88...|[{token, 0, 2, Th...|[{word_embeddings...|[{named_entity, 0...|[{chunk, 26, 45, ...|
# |10021332|Novel regulation ...|     Development|Homeotic genes ar...|           1999|[Amino Acid Seque...|[null, null, null...|[{document, 0, 15...|[{document, 0, 13...|[{token, 0, 7, Ho...|[{word_embeddings...|[{named_entity, 0...|[{chunk, 188, 210...|
# |10021333|Apontic binds the...|     Development|The product of th...|           1999|[3' Untranslated ...|[metabolism, null...|[{document, 0, 11...|[{document, 0, 14...|[{token, 0, 2, Th...|[{word_embeddings...|[{named_entity, 0...|[{chunk, 15, 28, ...|
# |10021334|Stromal cells med...|     Development|The essential rol...|           1999|[Animals, Cell Di...|[null, null, null...|[{document, 0, 19...|[{document, 0, 15...|[{token, 0, 2, Th...|[{word_embeddings...|[{named_entity, 0...|[{chunk, 22, 50, ...|
# |10021336|Inhibition of in ...|     Development|The terminal colo...|           1999|[Animals, Cell Ad...|[null, null, null...|[{document, 0, 17...|[{document, 0, 92...|[{token, 0, 2, Th...|[{word_embeddings...|[{named_entity, 0...|[{chunk, 22, 61, ...|
# |10021337|The Drosophila ki...|     Development|The Drosophila ki...|           1999|[Amino Acid Seque...|[null, null, null...|[{document, 0, 10...|[{document, 0, 12...|[{token, 0, 2, Th...|[{word_embeddings...|[{named_entity, 0...|[{chunk, 0, 25, T...|
# |10021338|FGF8 induces form...|     Development|Beads containing ...|           1999|[Animals, Body Pa...|[null, drug effec...|[{document, 0, 17...|[{document, 0, 14...|[{token, 0, 4, Be...|[{word_embeddings...|[{named_entity, 0...|[{chunk, 17, 32, ...|
# |10021339|Transcriptional r...|     Development|Early development...|           1999|[Animals, Animals...|[null, null, null...|[{document, 0, 19...|[{document, 0, 26...|[{token, 0, 4, Ea...|[{word_embeddings...|[{named_entity, 0...|[{chunk, 0, 54, E...|
# |10021341|The homeobox gene...|     Development|Left-right asymme...|           1999|[Abnormalities, M...|[embryology, null...|[{document, 0, 70...|[{document, 0, 10...|[{token, 0, 9, Le...|[{word_embeddings...|[{named_entity, 0...|[{chunk, 0, 34, L...|
# |10021343|Mrj encodes a Dna...|     Development|We have identifie...|           1999|[Allantois, Amino...|[abnormalities, n...|[{document, 0, 17...|[{document, 0, 12...|[{token, 0, 1, We...|[{word_embeddings...|[{named_entity, 0...|[{chunk, 19, 30, ...|
# |10021344|A Drosophila doub...|     Development|The Drosophila do...|           1999|[Amino Acid Seque...|[null, null, null...|[{document, 0, 93...|[{document, 0, 98...|[{token, 0, 2, Th...|[{word_embeddings...|[{named_entity, 0...|[{chunk, 136, 169...|
# |10021345|The cardiac homeo...|     Development|Csx/Nkx2.5 is a v...|           1999|[Animals, Cardiov...|[null, embryology...|[{document, 0, 21...|[{document, 0, 14...|[{token, 0, 9, Cs...|[{word_embeddings...|[{named_entity, 0...|[{chunk, 0, 9, Cs...|
# |10021346|Requirement of a ...|     Development|A novel gene, Xin...|           1999|[Amino Acid Seque...|[null, null, null...|[{document, 0, 20...|[{document, 0, 12...|[{token, 0, 0, A,...|[{word_embeddings...|[{named_entity, 0...|[{chunk, 0, 69, A...|
# |10021347|Characterization ...|     Development|On the basis of d...|           1999|[Alternative Spli...|[null, null, null...|[{document, 0, 17...|[{document, 0, 22...|[{token, 0, 1, On...|[{word_embeddings...|[{named_entity, 0...|[{chunk, 16, 44, ...|
# |10021350|Membrane-tethered...|     Development|Drosophila Armadi...|           1999|[Animals, Armadil...|[null, null, null...|[{document, 0, 15...|[{document, 0, 10...|[{token, 0, 9, Dr...|[{word_embeddings...|[{named_entity, 0...|[{chunk, 0, 19, D...|
# |10021463|Bcl-2 and Bcl-XL ...|J. Clin. Invest.|To maintain the i...|           1999|[Animals, Apoptos...|[null, null, null...|[{document, 0, 13...|[{document, 0, 10...|[{token, 0, 1, To...|[{word_embeddings...|[{named_entity, 0...|[{chunk, 51, 67, ...|
# |10021466|Chlamydial and hu...|J. Clin. Invest.|Both chlamydial a...|           1999|[Cells, Cultured,...|[null, immunology...|[{document, 0, 15...|[{document, 0, 14...|[{token, 0, 3, Bo...|[{word_embeddings...|[{named_entity, 0...|[{chunk, 5, 14, c...|
# |10022123|C-myc overexpress...|        Oncogene|p53 monitors geno...|           1999|[Animals, CDC2 Pr...|[null, metabolism...|[{document, 0, 12...|[{document, 0, 72...|[{token, 0, 2, p5...|[{word_embeddings...|[{named_entity, 0...|[{chunk, 101, 118...|
# |10022127|TIF1gamma, a nove...|        Oncogene|We report the clo...|           1999|[Amino Acid Seque...|[null, null, null...|[{document, 0, 13...|[{document, 0, 14...|[{token, 0, 1, We...|[{word_embeddings...|[{named_entity, 0...|[{chunk, 10, 20, ...|
# +--------+--------------------+----------------+--------------------+---------------+--------------------+--------------------+--------------------+--------------------+--------------------+--------------------+--------------------+--------------------+
# only showing top 20 rows

# %%
result.select('token.result','ner.result').show(truncate=100)
# Out:
# +----------------------------------------------------------------------------------------------------+----------------------------------------------------------------------------------------------------+
# |                                                                                              result|                                                                                              result|
# +----------------------------------------------------------------------------------------------------+----------------------------------------------------------------------------------------------------+
# |[The, nephric, duct, is, the, first, epithelial, tubule, to, differentiate, from, intermediate, m...|[O, O, O, O, O, O, O, O, O, O, O, B-PROBLEM, I-PROBLEM, O, O, O, O, B-PROBLEM, I-PROBLEM, I-PROBL...|
# |[The, overall, morphology, of, an, Arabidopsis, plant, depends, on, the, behaviour, of, its, meri...|[O, O, O, O, B-PROBLEM, I-PROBLEM, I-PROBLEM, O, O, O, O, O, O, O, O, B-PROBLEM, O, O, O, O, O, O...|
# |[Homeotic, genes, are, known, to, be, involved, in, patterning, morphological, structures, along,...|[O, O, O, O, O, O, O, O, O, O, O, O, O, O, O, O, O, O, O, O, O, O, O, O, O, O, O, O, B-PROBLEM, I...|
# |[The, product, of, the, oskar, gene, directs, posterior, patterning, in, the, Drosophila, oocyte,...|[O, O, O, B-PROBLEM, I-PROBLEM, I-PROBLEM, O, B-PROBLEM, I-PROBLEM, I-PROBLEM, I-PROBLEM, I-PROBL...|
# |[The, essential, role, of, vitamin, A, and, its, metabolites, ,, retinoids, ,, in, kidney, develo...|[O, O, O, O, B-PROBLEM, I-PROBLEM, I-PROBLEM, I-PROBLEM, I-PROBLEM, O, B-TREATMENT, O, O, O, O, O...|
# |[The, terminal, colon, is, aganglionic, in, mice, lacking, endothelin-3, or, its, receptor, ,, en...|[O, O, O, O, B-PROBLEM, I-PROBLEM, I-PROBLEM, I-PROBLEM, I-PROBLEM, O, O, O, O, B-TREATMENT, I-TR...|
# |[The, Drosophila, kismet, gene, was, identified, in, a, screen, for, dominant, suppressors, of, P...|[B-PROBLEM, I-PROBLEM, I-PROBLEM, I-PROBLEM, O, O, O, B-TEST, I-TEST, O, O, O, O, B-TREATMENT, O,...|
# |[Beads, containing, recombinant, FGF8, (, FGF8-beads, ), were, implanted, in, the, prospective, c...|[O, O, B-TREATMENT, I-TREATMENT, O, O, O, O, O, O, O, O, O, O, O, O, O, B-PROBLEM, I-PROBLEM, O, ...|
# |[Early, developmental, patterning, of, the, Drosophila, embryo, is, driven, by, the, activities, ...|[B-PROBLEM, I-PROBLEM, I-PROBLEM, I-PROBLEM, I-PROBLEM, I-PROBLEM, I-PROBLEM, O, O, O, O, O, O, O...|
# |[Left-right, asymmetry, in, vertebrates, is, controlled, by, activities, emanating, from, the, le...|[B-PROBLEM, I-PROBLEM, I-PROBLEM, I-PROBLEM, O, O, O, O, O, O, O, O, O, O, O, O, B-TEST, I-TEST, ...|
# |[We, have, identified, a, novel, gene, in, a, gene, trap, screen, that, encodes, a, protein, rela...|[O, O, O, B-PROBLEM, I-PROBLEM, I-PROBLEM, O, B-TEST, I-TEST, I-TEST, I-TEST, O, O, B-PROBLEM, I-...|
# |[The, Drosophila, doublesex, (, dsx, ), gene, encodes, a, transcription, factor, that, mediates, ...|[O, O, O, O, O, O, O, O, O, O, O, O, O, O, O, O, O, O, O, O, O, B-PROBLEM, I-PROBLEM, I-PROBLEM, ...|
# |[Csx/Nkx2.5, is, a, vertebrate, homeobox, gene, with, a, sequence, homology, to, the, Drosophila,...|[B-TEST, O, B-TREATMENT, I-TREATMENT, I-TREATMENT, I-TREATMENT, O, B-PROBLEM, I-PROBLEM, I-PROBLE...|
# |[A, novel, gene, ,, Xin, ,, from, chick, (, cXin, ), and, mouse, (, mXin, ), embryonic, hearts, ,...|[B-PROBLEM, I-PROBLEM, I-PROBLEM, I-PROBLEM, I-PROBLEM, I-PROBLEM, I-PROBLEM, I-PROBLEM, I-PROBLE...|
# |[On, the, basis, of, developmental, gene, expression, ,, the, vertebrate, central, nervous, syste...|[O, O, O, O, B-PROBLEM, I-PROBLEM, I-PROBLEM, O, O, O, O, O, O, O, O, O, O, O, O, O, O, O, O, O, ...|
# |[Drosophila, Armadillo, and, its, vertebrate, homolog, beta-catenin, are, key, effectors, of, Win...|[B-PROBLEM, I-PROBLEM, O, O, O, O, O, O, O, O, O, O, O, O, O, O, O, O, O, O, O, O, O, O, O, O, O,...|
# |[To, maintain, the, integrity, of, the, vascular, barrier, ,, endothelial, cells, (, EC, ), are, ...|[O, O, O, O, O, O, O, O, O, B-TEST, I-TEST, O, B-TEST, I-TEST, O, B-PROBLEM, I-PROBLEM, I-PROBLEM...|
# |[Both, chlamydial, and, human, heat, shock, protein, 60s, (, HSP, 60, ),, which, colocalize, in, ...|[O, B-PROBLEM, O, B-PROBLEM, I-PROBLEM, I-PROBLEM, I-PROBLEM, O, O, B-TEST, O, O, O, O, O, B-PROB...|
# |[p53, monitors, genomic, integrity, at, the, G1, and, G2/M, cell, cycle, checkpoints, ., Cells, l...|[O, O, O, O, O, O, O, O, O, O, O, O, O, O, O, O, O, O, B-PROBLEM, I-PROBLEM, O, O, O, B-PROBLEM, ...|
# |[We, report, the, cloning, and, characterization, of, a, novel, member, of, the, Transcriptional,...|[O, O, B-TREATMENT, I-TREATMENT, O, O, O, O, O, O, O, O, O, O, O, O, O, O, O, O, O, O, O, O, O, O...|
# +----------------------------------------------------------------------------------------------------+----------------------------------------------------------------------------------------------------+
# only showing top 20 rows

# %%
result_df = result.select(F.explode(F.arrays_zip("token.result","ner.result")).alias("cols"))\
                  .select(F.expr("cols['0']").alias("token"),
                          F.expr("cols['1']").alias("ner_label"))

result_df.show(50, truncate=100)
# Out:
# +---------------+---------+
# |          token|ner_label|
# +---------------+---------+
# |            The|        O|
# |        nephric|        O|
# |           duct|        O|
# |             is|        O|
# |            the|        O|
# |          first|        O|
# |     epithelial|        O|
# |         tubule|        O|
# |             to|        O|
# |  differentiate|        O|
# |           from|        O|
# |   intermediate|B-PROBLEM|
# |       mesoderm|I-PROBLEM|
# |           that|        O|
# |             is|        O|
# |      essential|        O|
# |            for|        O|
# |            all|B-PROBLEM|
# |        further|I-PROBLEM|
# |     urogenital|I-PROBLEM|
# |    development|I-PROBLEM|
# |              .|        O|
# |             In|        O|
# |           this|   B-TEST|
# |          study|   I-TEST|
# |             we|        O|
# |       identify|        O|
# |            the|        O|
# |         domain|        O|
# |             of|        O|
# |   intermediate|B-PROBLEM|
# |       mesoderm|I-PROBLEM|
# |           that|        O|
# |          gives|        O|
# |           rise|        O|
# |             to|        O|
# |            the|        O|
# |        nephric|        O|
# |           duct|        O|
# |            and|        O|
# |    demonstrate|        O|
# |           that|        O|
# |            the|        O|
# |        surface|        O|
# |       ectoderm|        O|
# |             is|        O|
# |       required|        O|
# |            for|        O|
# |            its|        O|
# |differentiation|        O|
# +---------------+---------+
# only showing top 50 rows

# %%
result_df.select("token", "ner_label")\
         .groupBy('ner_label').count()\
         .orderBy('count', ascending=False)\
         .show(truncate=False)
# Out:
# +-----------+-----+
# |ner_label  |count|
# +-----------+-----+
# |O          |16346|
# |I-PROBLEM  |2763 |
# |B-PROBLEM  |1207 |
# |I-TREATMENT|1061 |
# |I-TEST     |822  |
# |B-TREATMENT|789  |
# |B-TEST     |570  |
# +-----------+-----+

# %%
result.select(F.explode(F.arrays_zip('ner_chunk.result', 'ner_chunk.metadata')).alias("cols")) \
      .select(F.expr("cols['0']").alias("chunk"),
              F.expr("cols['1']['entity']").alias("ner_label")).show(truncate=False)
# Out:
# +------------------------------------+---------+
# |chunk                               |ner_label|
# +------------------------------------+---------+
# |intermediate mesoderm               |PROBLEM  |
# |all further urogenital development  |PROBLEM  |
# |this study                          |TEST     |
# |intermediate mesoderm               |PROBLEM  |
# |Removal of the surface ectoderm     |TREATMENT|
# |decreased levels                    |PROBLEM  |
# |Sim-1                               |TEST     |
# |mesenchymal nephric duct progenitors|TEST     |
# |inhibition of nephric duct formation|PROBLEM  |
# |subsequent kidney development       |PROBLEM  |
# |BMP-4                               |TREATMENT|
# |high-level BMP-4 expression         |TREATMENT|
# |a BMP-4-coated bead                 |TREATMENT|
# |Sim-1                               |TEST     |
# |nephric duct formation              |PROBLEM  |
# |BMP-4 signaling                     |TREATMENT|
# |nephric duct morphogenesis          |PROBLEM  |
# |that inductive interactions         |PROBLEM  |
# |nephric duct formation              |PROBLEM  |
# |urogenital development              |PROBLEM  |
# +------------------------------------+---------+
# only showing top 20 rows

# %%
# fullAnnotate in LightPipeline


print (samples_df.limit(1).collect()[0]['text'])

light_model = LightPipeline(model)

light_result = light_model.fullAnnotate(samples_df.limit(1).collect()[0]['text'])


chunks = []
entities = []
sentence= []
begin = []
end = []

for n in light_result[0]['ner_chunk']:
        
    begin.append(n.begin)
    end.append(n.end)
    chunks.append(n.result)
    entities.append(n.metadata['entity']) 
    sentence.append(n.metadata['sentence'])
    
    
import pandas as pd

df_clinical = pd.DataFrame({'chunks':chunks, 'begin': begin, 'end':end, 
                   'sentence_id':sentence, 'entities':entities})

df_clinical.head(20)
# Out:
# The nephric duct is the first epithelial tubule to differentiate from intermediate mesoderm that is essential for all further urogenital development. In this study we identify the domain of intermediate mesoderm that gives rise to the nephric duct and demonstrate that the surface ectoderm is required for its differentiation. Removal of the surface ectoderm resulted in decreased levels of Sim-1 and Pax-2 mRNA expression in mesenchymal nephric duct progenitors, and caused inhibition of nephric duct formation and subsequent kidney development. The surface ectoderm expresses BMP-4 and we show that it is required for the maintenance of high-level BMP-4 expression in lateral plate mesoderm. Addition of a BMP-4-coated bead to embryos lacking the surface ectoderm restored normal levels of Sim-1 and Pax-2 mRNA expression in nephric duct progenitors, nephric duct formation and the initiation of nephrogenesis. Thus, BMP-4 signaling can substitute for the surface ectoderm in supporting nephric duct morphogenesis. Collectively, these data suggest that inductive interactions between the surface ectoderm, lateral mesoderm and intermediate mesoderm are essential for nephric duct formation and the initiation of urogenital development.
#                                   chunks  begin   end sentence_id   entities
# 0                  intermediate mesoderm     70    90           0    PROBLEM
# 1     all further urogenital development    114   147           0    PROBLEM
# 2                             this study    153   162           1       TEST
# 3                  intermediate mesoderm    190   210           1    PROBLEM
# 4        Removal of the surface ectoderm    327   357           2  TREATMENT
# 5                       decreased levels    371   386           2    PROBLEM
# 6                                  Sim-1    391   395           2       TEST
# 7   mesenchymal nephric duct progenitors    426   461           2       TEST
# 8   inhibition of nephric duct formation    475   510           2    PROBLEM
# 9          subsequent kidney development    516   544           2    PROBLEM
# 10                                 BMP-4    578   582           3  TREATMENT
# 11           high-level BMP-4 expression    639   665           3  TREATMENT
# 12                   a BMP-4-coated bead    706   724           4  TREATMENT
# 13                                 Sim-1    792   796           4       TEST
# 14                nephric duct formation    853   874           4    PROBLEM
# 15                       BMP-4 signaling    919   933           5  TREATMENT
# 16            nephric duct morphogenesis    989  1014           5    PROBLEM
# 17           that inductive interactions   1050  1076           6    PROBLEM
# 18                nephric duct formation   1169  1190           6    PROBLEM
# 19                urogenital development   1214  1235           6    PROBLEM

# %%
from sparknlp_display import NerVisualizer

visualiser = NerVisualizer()

visualiser.display(light_result[0], label_col='ner_chunk', document_col='document', save_path="display_result.html")

# Change color of an entity label

#visualiser.set_label_colors({'PROBLEM':'#008080', 'TEST':'#800080', 'TREATMENT':'#808080'})
#visualiser.display(light_result[0], label_col='ner_chunk')

# Set label filter

# visualiser.display(light_result[0], label_col='ner_chunk', document_col='document',
                   #labels=['PROBLEM','TEST'])
# Out:
# <style>
#     @import url('https://fonts.googleapis.com/css2?family=Montserrat:wght@300;400;500;600;700&display=swap');
#     @import url('https://fonts.googleapis.com/css2?family=Vistol Regular:wght@300;400;500;600;700&display=swap');
#
#     .spark-nlp-display-scroll-entities {
#         border: 1px solid #E7EDF0;
#         border-radius: 3px;
#         text-align: justify;
#
#     }
#     .spark-nlp-display-scroll-entities span {
#         font-size: 14px;
#         line-height: 24px;
#         color: #536B76;
#         font-family: 'Montserrat', sans-serif !important;
#     }
#
#     .spark-nlp-display-entity-wrapper{
#
#         display: inline-grid;
#         text-align: center;
#         border-radius: 4px;
#         margin: 0 2px 5px 2px;
#         padding: 1px
#     }
#     .spark-nlp-display-entity-name{
#         font-size: 14px;
#         line-height: 24px;
#         font-family: 'Montserrat', sans-serif !important;
#
#         background: #f1f2f3;
#         border-width: medium;
#         text-align: center;
#
#         font-weight: 400;
#
#         border-radius: 5px;
#         padding: 2px 5px;
#         display: block;
#         margin: 3px 2px;
#
#     }
#     .spark-nlp-display-entity-type{
#         font-size: 14px;
#         line-height: 24px;
#         color: #ffffff;
#         font-family: 'Montserrat', sans-serif !important;
#
#         text-transform: uppercase;
#
#         font-weight: 500;
#
#         display: block;
#         padding: 3px 5px;
#     }
#
#     .spark-nlp-display-entity-resolution{
#         font-size: 14px;
#         line-height: 24px;
#         color: #ffffff;
#         font-family: 'Vistol Regular', sans-serif !important;
#
#         text-transform: uppercase;
#
#         font-weight: 500;
#
#         display: block;
#         padding: 3px 5px;
#     }
#
#     .spark-nlp-display-others{
#         font-size: 14px;
#         line-height: 24px;
#         font-family: 'Montserrat', sans-serif !important;
#
#         font-weight: 400;
#     }
#
# </style>
#  <span class="spark-nlp-display-others" style="background-color: white">The nephric duct is the first epithelial tubule to differentiate from </span><span class="spark-nlp-display-entity-wrapper" style="background-color: #800080"><span class="spark-nlp-display-entity-name">intermediate mesoderm </span><span class="spark-nlp-display-entity-type">PROBLEM</span></span><span class="spark-nlp-display-others" style="background-color: white"> that is essential for </span><span class="spark-nlp-display-entity-wrapper" style="background-color: #800080"><span class="spark-nlp-display-entity-name">all further urogenital development </span><span class="spark-nlp-display-entity-type">PROBLEM</span></span><span class="spark-nlp-display-others" style="background-color: white">. In </span><span class="spark-nlp-display-entity-wrapper" style="background-color: #77b5fe"><span class="spark-nlp-display-entity-name">this study </span><span class="spark-nlp-display-entity-type">TEST</span></span><span class="spark-nlp-display-others" style="background-color: white"> we identify the domain of </span><span class="spark-nlp-display-entity-wrapper" style="background-color: #800080"><span class="spark-nlp-display-entity-name">intermediate mesoderm </span><span class="spark-nlp-display-entity-type">PROBLEM</span></span><span class="spark-nlp-display-others" style="background-color: white"> that gives rise to the nephric duct and demonstrate that the surface ectoderm is required for its differentiation. </span><span class="spark-nlp-display-entity-wrapper" style="background-color: #8b6673"><span class="spark-nlp-display-entity-name">Removal of the surface ectoderm </span><span class="spark-nlp-display-entity-type">TREATMENT</span></span><span class="spark-nlp-display-others" style="background-color: white"> resulted in </span><span class="spark-nlp-display-entity-wrapper" style="background-color: #800080"><span class="spark-nlp-display-entity-name">decreased levels </span><span class="spark-nlp-display-entity-type">PROBLEM</span></span><span class="spark-nlp-display-others" style="background-color: white"> of </span><span class="spark-nlp-display-entity-wrapper" style="background-color: #77b5fe"><span class="spark-nlp-display-entity-name">Sim-1 </span><span class="spark-nlp-display-entity-type">TEST</span></span><span class="spark-nlp-display-others" style="background-color: white"> and Pax-2 mRNA expression in </span><span class="spark-nlp-display-entity-wrapper" style="background-color: #77b5fe"><span class="spark-nlp-display-entity-name">mesenchymal nephric duct progenitors </span><span class="spark-nlp-display-entity-type">TEST</span></span><span class="spark-nlp-display-others" style="background-color: white">, and caused </span><span class="spark-nlp-display-entity-wrapper" style="background-color: #800080"><span class="spark-nlp-display-entity-name">inhibition of nephric duct formation </span><span class="spark-nlp-display-entity-type">PROBLEM</span></span><span class="spark-nlp-display-others" style="background-color: white"> and </span><span class="spark-nlp-display-entity-wrapper" style="background-color: #800080"><span class="spark-nlp-display-entity-name">subsequent kidney development </span><span class="spark-nlp-display-entity-type">PROBLEM</span></span><span class="spark-nlp-display-others" style="background-color: white">. The surface ectoderm expresses </span><span class="spark-nlp-display-entity-wrapper" style="background-color: #8b6673"><span class="spark-nlp-display-entity-name">BMP-4 </span><span class="spark-nlp-display-entity-type">TREATMENT</span></span><span class="spark-nlp-display-others" style="background-color: white"> and we show that it is required for the maintenance of </span><span class="spark-nlp-display-entity-wrapper" style="background-color: #8b6673"><span class="spark-nlp-display-entity-name">high-level BMP-4 expression </span><span class="spark-nlp-display-entity-type">TREATMENT</span></span><span class="spark-nlp-d ...
